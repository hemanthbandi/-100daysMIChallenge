# %%
import pandas as pd

# %%
data = pd.read_excel('C:\\Users\\heman\\OneDrive\\Desktop\\TitanicDataset\\titanic3.xls',encoding = "ISO-8859-1")

# %%
data.head(10)
data.shape
# Out:
# (1309, 14)

# %%
data.drop(data.columns[[2]],axis=1,inplace=True)
data.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch  ticket      fare    cabin  \
# 0       1         1  female  29.0000      0      0   24160  211.3375       B5
# 1       1         1    male   0.9167      1      2  113781  151.5500  C22 C26
# 2       1         0  female   2.0000      1      2  113781  151.5500  C22 C26
# 3       1         0    male  30.0000      1      2  113781  151.5500  C22 C26
# 4       1         0  female  25.0000      1      2  113781  151.5500  C22 C26
#
#   embarked boat   body                        home.dest
# 0        S    2    NaN                     St Louis, MO
# 1        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4        S  NaN    NaN  Montreal, PQ / Chesterville, ON

# %%
data.set_index('ticket')
data.shape
# Out:
# (1309, 13)

# %%
data.iloc[0]
# Out:
# pclass                  1
# survived                1
# sex                female
# age                    29
# sibsp                   0
# parch                   0
# ticket              24160
# fare              211.338
# cabin                  B5
# embarked                S
# boat                    2
# body                  NaN
# home.dest    St Louis, MO
# Name: 0, dtype: object

# %%
data.iloc[0:8]
# Out:
#    pclass  survived     sex      age  sibsp  parch  ticket      fare    cabin  \
# 0       1         1  female  29.0000      0      0   24160  211.3375       B5
# 1       1         1    male   0.9167      1      2  113781  151.5500  C22 C26
# 2       1         0  female   2.0000      1      2  113781  151.5500  C22 C26
# 3       1         0    male  30.0000      1      2  113781  151.5500  C22 C26
# 4       1         0  female  25.0000      1      2  113781  151.5500  C22 C26
# 5       1         1    male  48.0000      0      0   19952   26.5500      E12
# 6       1         1  female  63.0000      1      0   13502   77.9583       D7
# 7       1         0    male  39.0000      0      0  112050    0.0000      A36
#
#   embarked boat   body                        home.dest
# 0        S    2    NaN                     St Louis, MO
# 1        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...

# %%
data.loc[:,['age']]
# Out:
#           age
# 0     29.0000
# 1      0.9167
# 2      2.0000
# 3     30.0000
# 4     25.0000
# 5     48.0000
# 6     63.0000
# 7     39.0000
# 8     53.0000
# 9     71.0000
# 10    47.0000
# 11    18.0000
# 12    24.0000
# 13    26.0000
# 14    80.0000
# 15        NaN
# 16    24.0000
# 17    50.0000
# 18    32.0000
# 19    36.0000
# 20    37.0000
# 21    47.0000
# 22    26.0000
# 23    42.0000
# 24    29.0000
# 25    25.0000
# 26    25.0000
# 27    19.0000
# 28    35.0000
# 29    28.0000
# ...       ...
# 1279  14.0000
# 1280  22.0000
# 1281  22.0000
# 1282      NaN
# 1283      NaN
# 1284      NaN
# 1285  32.5000
# 1286  38.0000
# 1287  51.0000
# 1288  18.0000
# 1289  21.0000
# 1290  47.0000
# 1291      NaN
# 1292      NaN
# 1293      NaN
# 1294  28.5000
# 1295  21.0000
# 1296  27.0000
# 1297      NaN
# 1298  36.0000
# 1299  27.0000
# 1300  15.0000
# 1301  45.5000
# 1302      NaN
# 1303      NaN
# 1304  14.5000
# 1305      NaN
# 1306  26.5000
# 1307  27.0000
# 1308  29.0000
#
# ...

# %%
data.loc[:,'age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
# 5       48.0000
# 6       63.0000
# 7       39.0000
# 8       53.0000
# 9       71.0000
# 10      47.0000
# 11      18.0000
# 12      24.0000
# 13      26.0000
# 14      80.0000
# 15          NaN
# 16      24.0000
# 17      50.0000
# 18      32.0000
# 19      36.0000
# 20      37.0000
# 21      47.0000
# 22      26.0000
# 23      42.0000
# 24      29.0000
# 25      25.0000
# 26      25.0000
# 27      19.0000
# 28      35.0000
# 29      28.0000
#          ...
# 1279    14.0000
# 1280    22.0000
# 1281    22.0000
# 1282        NaN
# 1283        NaN
# 1284        NaN
# 1285    32.5000
# 1286    38.0000
# 1287    51.0000
# 1288    18.0000
# 1289    21.0000
# 1290    47.0000
# 1291        NaN
# 1292        NaN
# 1293        NaN
# 1294    28.5000
# 1295    21.0000
# 1296    27.0000
# 1297        NaN
# 1298    36.0000
# 1299    27.0000
# 1300    15.0000
# 1301    45.5000
# 1302        NaN
# ...

# %%
data.loc[data['age']>=50]
# Out:
#       pclass  survived     sex   age  sibsp  parch        ticket      fare  \
# 6          1         1  female  63.0      1      0         13502   77.9583
# 8          1         1  female  53.0      2      0         11769   51.4792
# 9          1         0    male  71.0      0      0      PC 17609   49.5042
# 14         1         1    male  80.0      0      0         27042   30.0000
# 17         1         1  female  50.0      0      1      PC 17558  247.5208
# 33         1         1  female  58.0      0      0        113783   26.5500
# 42         1         1  female  59.0      2      0         11769   51.4792
# 43         1         1  female  60.0      0      0         11813   76.2917
# 48         1         1  female  53.0      0      0      PC 17606   27.4458
# 50         1         1  female  58.0      0      1      PC 17755  512.3292
# 61         1         1  female  76.0      1      0         19877   78.8500
# ...

# %%
data.loc[:,['age','home.dest']]
# Out:
#           age                           home.dest
# 0     29.0000                        St Louis, MO
# 1      0.9167     Montreal, PQ / Chesterville, ON
# 2      2.0000     Montreal, PQ / Chesterville, ON
# 3     30.0000     Montreal, PQ / Chesterville, ON
# 4     25.0000     Montreal, PQ / Chesterville, ON
# 5     48.0000                        New York, NY
# 6     63.0000                          Hudson, NY
# 7     39.0000                         Belfast, NI
# 8     53.0000                 Bayside, Queens, NY
# 9     71.0000                 Montevideo, Uruguay
# 10    47.0000                        New York, NY
# 11    18.0000                        New York, NY
# 12    24.0000                       Paris, France
# 13    26.0000                                 NaN
# 14    80.0000                       Hessle, Yorks
# 15        NaN                        New York, NY
# 16    24.0000                        Montreal, PQ
# 17    50.0000                        Montreal, PQ
# ...

# %%
data.head(5)
# Out:
#   firstname Age grades
# 0   Hemanth  26      A
# 1    Ashrad  27      A
# 2     Meena  28      A
# 3      Abhi  29      A
# 4   Hemanth  30      A

# %%
data = data[['pclass','survived','sex','age','sibsp','parch','fare','cabin','embarked']]
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-14daedf15533> in <module>()
# ----> 1 data = data[['pclass','survived','sex','age','sibsp','parch','fare','cabin','embarked']]
#       2 data
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
# ...

# %%
data = pd.read_excel('C:\\Users\\heman\\OneDrive\\Desktop\\TitanicDataset\\titanic3.xls',encoding = "ISO-8859-1")
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data = data[['pclass','survived','sex','age','sibsp','parch','fare','cabin','embarked']]
data.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare    cabin embarked
# 0       1         1  female  29.0000      0      0  211.3375       B5        S
# 1       1         1    male   0.9167      1      2  151.5500  C22 C26        S
# 2       1         0  female   2.0000      1      2  151.5500  C22 C26        S
# 3       1         0    male  30.0000      1      2  151.5500  C22 C26        S
# 4       1         0  female  25.0000      1      2  151.5500  C22 C26        S

# %%
data.drop('embarked',axis = 1,inplace = True)

# %%
data.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare    cabin
# 0       1         1  female  29.0000      0      0  211.3375       B5
# 1       1         1    male   0.9167      1      2  151.5500  C22 C26
# 2       1         0  female   2.0000      1      2  151.5500  C22 C26
# 3       1         0    male  30.0000      1      2  151.5500  C22 C26
# 4       1         0  female  25.0000      1      2  151.5500  C22 C26

# %%
data.drop(['embarked','cabin','fare',axis = 1,inplace = True)

# %%
data.tail(20)
# Out:
#       pclass  survived     sex   age  sibsp  parch
# 1289       3         0    male  21.0      1      0
# 1290       3         1  female  47.0      1      0
# 1291       3         0    male   NaN      0      0
# 1292       3         0    male   NaN      0      0
# 1293       3         0    male   NaN      0      0
# 1294       3         0    male  28.5      0      0
# 1295       3         0    male  21.0      0      0
# 1296       3         0    male  27.0      0      0
# 1297       3         0    male   NaN      0      0
# 1298       3         0    male  36.0      0      0
# 1299       3         0    male  27.0      1      0
# 1300       3         1  female  15.0      1      0
# 1301       3         0    male  45.5      0      0
# 1302       3         0    male   NaN      0      0
# 1303       3         0    male   NaN      0      0
# 1304       3         0  female  14.5      1      0
# 1305       3         0  female   NaN      1      0
# ...

# %%
data['age'].fillna(data['age'].mean(),inplace=True)
data.tail(20)
# Out:
#       pclass  survived     sex        age  sibsp  parch
# 1289       3         0    male  21.000000      1      0
# 1290       3         1  female  47.000000      1      0
# 1291       3         0    male  29.881135      0      0
# 1292       3         0    male  29.881135      0      0
# 1293       3         0    male  29.881135      0      0
# 1294       3         0    male  28.500000      0      0
# 1295       3         0    male  21.000000      0      0
# 1296       3         0    male  27.000000      0      0
# 1297       3         0    male  29.881135      0      0
# 1298       3         0    male  36.000000      0      0
# 1299       3         0    male  27.000000      1      0
# 1300       3         1  female  15.000000      1      0
# 1301       3         0    male  45.500000      0      0
# 1302       3         0    male  29.881135      0      0
# 1303       3         0    male  29.881135      0      0
# 1304       3         0  female  14.500000      1      0
# ...

# %%
data['sex']=data['sex'].map({'male':0,'female':1})
data
# Out:
#       pclass  survived  sex        age  sibsp  parch
# 0          1         1    1  29.000000      0      0
# 1          1         1    0   0.916700      1      2
# 2          1         0    1   2.000000      1      2
# 3          1         0    0  30.000000      1      2
# 4          1         0    1  25.000000      1      2
# 5          1         1    0  48.000000      0      0
# 6          1         1    1  63.000000      1      0
# 7          1         0    0  39.000000      0      0
# 8          1         1    1  53.000000      2      0
# 9          1         0    0  71.000000      0      0
# 10         1         0    0  47.000000      1      0
# 11         1         1    1  18.000000      1      0
# 12         1         1    1  24.000000      0      0
# 13         1         1    1  26.000000      0      0
# 14         1         1    0  80.000000      0      0
# 15         1         0    0  29.881135      0      0
# 16         1         0    0  24.000000      0      1
# ...

# %%
data.to_csv(r'C:\Users\heman\OneDrive\Desktop\TitanicDataset\cleansedtitanic.csv',encoding='ISO-8859-1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
# pclass      1309 non-null int64
# survived    1309 non-null int64
# sex         1309 non-null object
# age         1046 non-null float64
# sibsp       1309 non-null int64
# parch       1309 non-null int64
# fare        1308 non-null float64
# cabin       295 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 81.9+ KB

# %%
raw_data = {'firstname' : ['Hemanth','Ashrad','Meena','Abhi','Hemanth','Hemanth','Hemanth'],
           'Age':['26','27','28','29','30','31','32'],
           'grades':['A','A','A','A','A','A','A',]}
data = pd.DataFrame(raw_data)
data
# Out:
#   firstname Age grades
# 0   Hemanth  26      A
# 1    Ashrad  27      A
# 2     Meena  28      A
# 3      Abhi  29      A
# 4   Hemanth  30      A
# 5   Hemanth  31      A
# 6   Hemanth  32      A

# %%
data.drop_duplicates(['firstname'])
# Out:
#   firstname Age grades
# 0   Hemanth  26      A
# 1    Ashrad  27      A
# 2     Meena  28      A
# 3      Abhi  29      A
