# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_test = pd.read_csv(r'C:\Users\heman\OneDrive\Desktop\Datascience\Datasets\Sales\Test.csv')
data_test['Source'] = 'test'

# %%
data_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type Source
# ...

# %%
data_train=pd.read_csv(r'C:/Users/heman/OneDrive/Desktop/Datascience/Datasets/Sales/Train.csv')
data_train['Source'] = 'train'

# %%
data = pd.concat([data_test,data_train],sort=True)
data.head()
# Out:
#   Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales    Item_Type  \
# 0          Low Fat           FDW58  107.8622                NaN  Snack Foods
# 1              reg           FDW14   87.3198                NaN        Dairy
# 2          Low Fat           NCN55  241.7538                NaN       Others
# 3          Low Fat           FDQ58  155.0340                NaN  Snack Foods
# 4          Regular           FDY38  234.2300                NaN        Dairy
#
#    Item_Visibility  Item_Weight  Outlet_Establishment_Year Outlet_Identifier  \
# 0         0.007565       20.750                       1999            OUT049
# 1         0.038428        8.300                       2007            OUT017
# 2         0.099575       14.600                       1998            OUT010
# 3         0.015388        7.315                       2007            OUT017
# 4         0.118599          NaN                       1985            OUT027
#
# ...

# %%
data['Item_Outlet_Sales']=data['Item_Outlet_Sales'].fillna(0)

# %%
data['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
# Item_fat_content series has Regular entered as reg like so, Let's change them as required 
data['Item_Fat_Content'] = data['Item_Fat_Content'].map({'Regular':'Regular','reg':'Regular','Low Fat':'Low Fat','LF':'Low Fat','low fat':'Low Fat'})

# %%
# notice that the values changed
data['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
data.isnull().sum(axis=0)
# Out:
# Item_Fat_Content                0
# Item_Identifier                 0
# Item_MRP                        0
# Item_Outlet_Sales               0
# Item_Type                       0
# Item_Visibility                 0
# Item_Weight                  2439
# Outlet_Establishment_Year       0
# Outlet_Identifier               0
# Outlet_Location_Type            0
# Outlet_Size                  4016
# Outlet_Type                     0
# Source                          0
# dtype: int64

# %%
#data['Item_Type'== 'Snack Foods'].value_counts()
Snackfood = data[data['Item_Type'] =='Snack Foods']
Dairyfood=data[data['Item_Type'] =='Dairyfood']
Others=data[data['Item_Type'] =='Others']
FandV=data[data['Item_Type'] =='Fruits and Vegetables']
Baking=data[data['Item_Type'] =='Baking Goods']
HandH=data[data['Item_Type'] =='Health and Hygiene']
bread=data[data['Item_Type'] =='Breads']
HardDrinks=data[data['Item_Type'] =='Hard Drinks']
Seafood=data[data['Item_Type'] =='Seafood']
Soft_drinks=data[data['Item_Type'] =='Soft Drinks']
Household=data[data['Item_Type'] =='Household']
Frozenfood=data[data['Item_Type'] =='Frozen Foods']
Meat=data[data['Item_Type'] =='Meat']
Canned=data[data['Item_Type'] =='Canned']
StarchyFood=data[data['Item_Type'] =='Starchy Foods']
Breakfast=data[data['Item_Type'] =='Breakfast']

# %%
data.head()
# Out:
#   Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales    Item_Type  \
# 0          Low Fat           FDW58  107.8622                0.0  Snack Foods
# 1          Regular           FDW14   87.3198                0.0        Dairy
# 2          Low Fat           NCN55  241.7538                0.0       Others
# 3          Low Fat           FDQ58  155.0340                0.0  Snack Foods
# 4          Regular           FDY38  234.2300                0.0        Dairy
#
#    Item_Visibility  Item_Weight  Outlet_Establishment_Year Outlet_Identifier  \
# 0         0.007565       20.750                       1999            OUT049
# 1         0.038428        8.300                       2007            OUT017
# 2         0.099575       14.600                       1998            OUT010
# 3         0.015388        7.315                       2007            OUT017
# 4         0.118599          NaN                       1985            OUT027
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
variables = ['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Location_Type','Outlet_Size','Outlet_Type']
for i in variables:
    data[i] = le.fit_transform(data[i].astype(str))

# %%
data.head()
# Out:
#    Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales  Item_Type  \
# 0                 0           FDW58  107.8622                0.0         13
# 1                 1           FDW14   87.3198                0.0          4
# 2                 0           NCN55  241.7538                0.0         11
# 3                 0           FDQ58  155.0340                0.0         13
# 4                 1           FDY38  234.2300                0.0          4
#
#    Item_Visibility  Item_Weight  Outlet_Establishment_Year  Outlet_Identifier  \
# 0         0.007565       20.750                       1999                  9
# 1         0.038428        8.300                       2007                  2
# 2         0.099575       14.600                       1998                  0
# 3         0.015388        7.315                       2007                  2
# 4         0.118599          NaN                       1985                  5
#
# ...

# %%
data.drop('Item_Identifier',axis=True,inplace=True)
data.head()
# Out:
#    Item_Fat_Content  Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  \
# 0                 0  107.8622                0.0         13         0.007565
# 1                 1   87.3198                0.0          4         0.038428
# 2                 0  241.7538                0.0         11         0.099575
# 3                 0  155.0340                0.0         13         0.015388
# 4                 1  234.2300                0.0          4         0.118599
#
#    Item_Weight  Outlet_Establishment_Year  Outlet_Identifier  \
# 0       20.750                       1999                  9
# 1        8.300                       2007                  2
# 2       14.600                       1998                  0
# 3        7.315                       2007                  2
# 4          NaN                       1985                  5
#
#    Outlet_Location_Type  Outlet_Size  Outlet_Type Source
# 0                     0            1            1   test
# ...

# %%
data['Outlet_years'] = 2018- data['Outlet_Establishment_Year']

# %%
data.head()
# Out:
#    Item_Fat_Content  Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  \
# 0                 0  107.8622                0.0         13         0.007565
# 1                 1   87.3198                0.0          4         0.038428
# 2                 0  241.7538                0.0         11         0.099575
# 3                 0  155.0340                0.0         13         0.015388
# 4                 1  234.2300                0.0          4         0.118599
#
#    Item_Weight  Outlet_Establishment_Year  Outlet_Identifier  \
# 0       20.750                       1999                  9
# 1        8.300                       2007                  2
# 2       14.600                       1998                  0
# 3        7.315                       2007                  2
# 4          NaN                       1985                  5
#
#    Outlet_Location_Type  Outlet_Size  Outlet_Type Source  Outlet_years
# ...

# %%
data.describe()
# Out:
#        Item_Fat_Content      Item_MRP  Item_Outlet_Sales     Item_Type  \
# count      14204.000000  14204.000000       14204.000000  14204.000000
# mean           0.353351    141.004977        1308.865489      7.229372
# std            0.478027     62.086938        1699.791423      4.213471
# min            0.000000     31.290000           0.000000      0.000000
# 25%            0.000000     94.012000           0.000000      4.000000
# 50%            0.000000    142.247000         559.272000      6.000000
# 75%            1.000000    185.855600        2163.184200     10.000000
# max            1.000000    266.888400       13086.964800     15.000000
#
#        Item_Visibility   Item_Weight  Outlet_Establishment_Year  \
# count     14204.000000  11765.000000               14204.000000
# mean          0.065953     12.792854                1997.830681
# std           0.051459      4.652502                   8.371664
# min           0.000000      4.555000                1985.000000
# ...

# %%
data.isnull().sum()
# Out:
# Item_Fat_Content                0
# Item_MRP                        0
# Item_Outlet_Sales               0
# Item_Type                       0
# Item_Visibility                 0
# Item_Weight                  2439
# Outlet_Establishment_Year       0
# Outlet_Identifier               0
# Outlet_Location_Type            0
# Outlet_Size                     0
# Outlet_Type                     0
# Source                          0
# Outlet_years                    0
# dtype: int64

# %%
data['Item_Weight']=data['Item_Weight'].fillna(data['Item_Weight'].mean())

# %%
data.isnull().sum()
# Out:
# Item_Fat_Content             0
# Item_MRP                     0
# Item_Outlet_Sales            0
# Item_Type                    0
# Item_Visibility              0
# Item_Weight                  0
# Outlet_Establishment_Year    0
# Outlet_Identifier            0
# Outlet_Location_Type         0
# Outlet_Size                  0
# Outlet_Type                  0
# Source                       0
# Outlet_years                 0
# dtype: int64

# %%
data.head()
# Out:
#    Item_Fat_Content  Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  \
# 0                 0  107.8622                0.0         13         0.007565
# 1                 1   87.3198                0.0          4         0.038428
# 2                 0  241.7538                0.0         11         0.099575
# 3                 0  155.0340                0.0         13         0.015388
# 4                 1  234.2300                0.0          4         0.118599
#
#    Item_Weight  Outlet_Establishment_Year  Outlet_Identifier  \
# 0    20.750000                       1999                  9
# 1     8.300000                       2007                  2
# 2    14.600000                       1998                  0
# 3     7.315000                       2007                  2
# 4    12.792854                       1985                  5
#
#    Outlet_Location_Type  Outlet_Size  Outlet_Type Source  Outlet_years
# ...

# %%
data = pd.get_dummies(data, columns=['Item_Fat_Content','Outlet_Location_Type','Outlet_Size','Outlet_Type'])

# %%
data.head()
# Out:
#    Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  Item_Weight  \
# 0  107.8622                0.0         13         0.007565    20.750000
# 1   87.3198                0.0          4         0.038428     8.300000
# 2  241.7538                0.0         11         0.099575    14.600000
# 3  155.0340                0.0         13         0.015388     7.315000
# 4  234.2300                0.0          4         0.118599    12.792854
#
#    Outlet_Establishment_Year  Outlet_Identifier Source  Outlet_years  \
# 0                       1999                  9   test            19
# 1                       2007                  2   test            11
# 2                       1998                  0   test            20
# 3                       2007                  2   test            11
# 4                       1985                  5   test            33
#
#    Item_Fat_Content_0      ...        Outlet_Location_Type_1  \
# ...

# %%
data_train = data[data['Source'] == 'train']
data_test = data[data['Source'] == 'test']
data_train.to_csv(r"C:\Users\heman\OneDrive\Desktop\Datascience\Datasets\Sales\TrainedData.csv",index=False)
data_test.to_csv(r"C:\Users\heman\OneDrive\Desktop\Datascience\Datasets\Sales\TestData.csv",index=False)

# %%
dataa = pd.read_csv(r"C:\Users\heman\OneDrive\Desktop\Datascience\Datasets\Sales\TrainedData.csv")
dataa.head()
# Out:
#    Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  Item_Weight  \
# 0  249.8092          3735.1380          4         0.016047         9.30
# 1   48.2692           443.4228         14         0.019278         5.92
# 2  141.6180          2097.2700         10         0.016760        17.50
# 3  182.0950           732.3800          6         0.000000        19.20
# 4   53.8614           994.7052          9         0.000000         8.93
#
#    Outlet_Establishment_Year  Outlet_Identifier Source  Outlet_years  \
# 0                       1999                  9  train            19
# 1                       2009                  3  train             9
# 2                       1999                  9  train            19
# 3                       1998                  0  train            20
# 4                       1987                  1  train            31
#
#    Item_Fat_Content_0      ...        Outlet_Location_Type_1  \
# ...

# %%
len(dataa.columns)
# Out:
# 22

# %%
Data_sales = dataa['Item_Outlet_Sales']
#Data_sales.head()
Data_nosales = dataa.drop(['Item_Outlet_Sales'],axis=True)

# %%
Data_nosales.drop(['Source'],axis=True,inplace=True)

# %%
Data_nosales.head()
# Out:
#    Item_MRP  Item_Type  Item_Visibility  Item_Weight  \
# 0  249.8092          4         0.016047         9.30
# 1   48.2692         14         0.019278         5.92
# 2  141.6180         10         0.016760        17.50
# 3  182.0950          6         0.000000        19.20
# 4   53.8614          9         0.000000         8.93
#
#    Outlet_Establishment_Year  Outlet_Identifier  Outlet_years  \
# 0                       1999                  9            19
# 1                       2009                  3             9
# 2                       1999                  9            19
# 3                       1998                  0            20
# 4                       1987                  1            31
#
#    Item_Fat_Content_0  Item_Fat_Content_1  Outlet_Location_Type_0  \
# 0                   1                   0                       1
# 1                   0                   1                       0
# 2                   1                   0                       1
# ...

# %%
data_tested = pd.read_csv(r"C:/Users/heman/OneDrive/Desktop/Datascience/Datasets/Sales/TestData.csv")
data_tested.drop('Source',axis=True,inplace=True)
# Out:
#    Item_MRP  Item_Outlet_Sales  Item_Type  Item_Visibility  Item_Weight  \
# 0  107.8622                0.0         13         0.007565    20.750000
# 1   87.3198                0.0          4         0.038428     8.300000
# 2  241.7538                0.0         11         0.099575    14.600000
# 3  155.0340                0.0         13         0.015388     7.315000
# 4  234.2300                0.0          4         0.118599    12.792854
#
#    Outlet_Establishment_Year  Outlet_Identifier  Outlet_years  \
# 0                       1999                  9            19
# 1                       2007                  2            11
# 2                       1998                  0            20
# 3                       2007                  2            11
# 4                       1985                  5            33
#
#    Item_Fat_Content_0  Item_Fat_Content_1      ...        \
# 0                   1                   0      ...
# ...

# %%
data_tested.drop('Item_Outlet_Sales',axis=True,inplace=True)

# %%
len(data_tested.columns)
# Out:
# 21

# %%
from sklearn.tree import DecisionTreeRegressor
pred = DecisionTreeRegressor()

# %%
pred.fit(Data_nosales,Data_sales)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred.predict(Data_nosales.loc[0:1,:])
# Out:
# array([3735.138 ,  443.4228])

# %%
pred.predict(data_tested.loc[0:1,:])
# Out:
# array([1693.7952,  959.4178])

# %%
from sklearn.cross_validation import cross_val_score
cross_val_score(pred,Data_nosales,Data_sales)
# Out:
# array([0.19535584, 0.16570285, 0.2027615 ])

# %%
DTR_Score = pred.score(Data_nosales,Data_sales)
DTR_Score
# Out:
# 1.0
